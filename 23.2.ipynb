# %% [markdown]
# <a href="https://colab.research.google.com/github/namdo31251027063-bit/BAI_TAP/blob/main/23.2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from geopy.geocoders import Nominatim
geolocator=Nominatim(user_agent="geoapi")
location=geolocator.geocode("Ben Thanh Market,Ho Chi Minh")
location_1=geolocator.geocode("Đại học Kinh Tế Thành Phố Hồ Chí Minh cơ sở a, Ho Chi Minh City, Vietnam")
location_2=geolocator.geocode("Đại học Kinh Tế Thành Phố Hồ Chí Minh cơ sở b, Ho Chi Minh City, Vietnam")
location_3=geolocator.geocode("Đại học Kinh Tế Thành Phố Hồ Chí Minh cơ sở c, Ho Chi Minh City, Vietnam")
location_4=geolocator.geocode("Đại học Kinh Tế Thành Phố Hồ Chí Minh cơ sở d, Ho Chi Minh City, Vietnam")
location_5=geolocator.geocode("Phố đi bộ Nguyễn Huệ, Ho Chi Minh City, Vietnam")
location_6=geolocator.geocode("Bách Khoa university, Ho Chi Minh City, Vietnam")
location_7=geolocator.geocode("Nhà thờ Đức Bà,Ho Chi Minh")
location_8=geolocator.geocode("Dinh Độc Lập,Ho Chi Minh")
location_9=geolocator.geocode("Landmark 81,Ho Chi Minh")
print(f"ten:{location_1.address}")
print(f"toa do:{location_1.latitude},{location_1.longitude}")
print(f"ten:{location.address}")
print(f"toa do:{location.latitude},{location.longitude}")
print(f"ten:{location_2.address}")
print(f"toa do:{location_2.latitude},{location_2.longitude}")
print(f"ten:{location_3.address}")
print(f"toa do:{location_3.latitude},{location_3.longitude}")
print(f"ten:{location_4.address}")
print(f"toa do:{location_4.latitude},{location_4.longitude}")
print(f"ten:{location_5.address}")
print(f"toa do:{location_5.latitude},{location_5.longitude}")
print(f"ten:{location_6.address}")
print(f"toa do:{location_6.latitude},{location_6.longitude}")
print(f"ten:{location_7.address}")
print(f"toa do:{location_7.latitude},{location_7.longitude}")
print(f"ten:{location_8.address}")
print(f"toa do:{location_8.latitude},{location_8.longitude}")
print(f"ten:{location_9.address}")
print(f"toa do:{location_9.latitude},{location_9.longitude}")

# %%
import folium
from geopy.geocoders import Nominatim
from geopy.distance import geodesic

# Khởi tạo
geolocator = Nominatim(user_agent="geoapi")

# Điểm trung tâm (chọn Bến Thành)
center = geolocator.geocode("Ben Thanh Market, Ho Chi Minh City")
center_coords = (center.latitude, center.longitude)

# Danh sách địa điểm
places = [
    "Đại học Kinh Tế Thành Phố Hồ Chí Minh cơ sở a, Ho Chi Minh City, Vietnam",
    "Đại học Kinh Tế Thành Phố Hồ Chí Minh cơ sở b, Ho Chi Minh City, Vietnam",
    "Đại học Kinh Tế Thành Phố Hồ Chí Minh cơ sở c, Ho Chi Minh City, Vietnam",
    "Đại học Kinh Tế Thành Phố Hồ Chí Minh cơ sở d, Ho Chi Minh City, Vietnam",
    "Phố đi bộ Nguyễn Huệ, Ho Chi Minh City, Vietnam",
    "Bách Khoa university, Ho Chi Minh City, Vietnam",
    "Nhà thờ Đức Bà, Ho Chi Minh",
    "Dinh Độc Lập, Ho Chi Minh",
    "Landmark 81, Ho Chi Minh"
]

# Tạo bản đồ
m = folium.Map(location=center_coords, zoom_start=13)

# Marker trung tâm
folium.Marker(center_coords,popup="Trung tâm: Bến Thành",icon=folium.Icon(color="red")).add_to(m)

# Duyệt từng địa điểm
for place in places:
    location = geolocator.geocode(place)

    if location:
        coords = (location.latitude, location.longitude)

        # Tính khoảng cách
        distance = geodesic(center_coords, coords).km

        # Marker
        folium.Marker(coords,popup=f"{place}\nKhoảng cách: {distance:.2f} km",icon=folium.Icon(color="blue")).add_to(m)

m
# Out:
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=Ben+Thanh+Market%2C+Ho+Chi+Minh+City&format=json&limit=1
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_74ff795a9d76d1097d34df80897306bf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_74ff795a9d76d1097d34df80897306bf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_74ff795a9d76d1097d34df80897306bf = L.map(
#                 &quot;map_74ff795a9d76d1097d34df80897306bf&quot;,
#                 {
#                     center: [10.7725301, 106.6980365],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_522fbcc3c239d33fd1f1864104fab639 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_522fbcc3c239d33fd1f1864104fab639.addTo(map_74ff795a9d76d1097d34df80897306bf);
#
#
#             var marker_bf758ac5c20a00d31aca326594dd0524 = L.marker(
#                 [10.7725301, 106.6980365],
#                 {
# }
#             ).addTo(map_74ff795a9d76d1097d34df80897306bf);
#
#
#             var icon_e1298ecaae3a433f258676a1f76545d0 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_b011133807b9bade5c1fa9c1799f50de = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e52b83721086841c7d5c7c9f3acc063 = $(`&lt;div id=&quot;html_0e52b83721086841c7d5c7c9f3acc063&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Trung tâm: Bến Thành&lt;/div&gt;`)[0];
#                 popup_b011133807b9bade5c1fa9c1799f50de.setContent(html_0e52b83721086841c7d5c7c9f3acc063);
#
#
#
#         marker_bf758ac5c20a00d31aca326594dd0524.bindPopup(popup_b011133807b9bade5c1fa9c1799f50de)
#         ;
#
#
#
#
#                 marker_bf758ac5c20a00d31aca326594dd0524.setIcon(icon_e1298ecaae3a433f258676a1f76545d0);
#
#
#             var marker_baed84f1017ed788a1a97804bd8f3aa4 = L.marker(
#                 [10.7830141, 106.6948927],
#                 {
# }
#             ).addTo(map_74ff795a9d76d1097d34df80897306bf);
#
#
#             var icon_0ae15e1abe1de6a58a7dc09354e119ec = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_99649d6b8b7917a53c0aaa7dd2159971 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe1e203db46ace340ad02bc24ed88107 = $(`&lt;div id=&quot;html_fe1e203db46ace340ad02bc24ed88107&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Đại học Kinh Tế Thành Phố Hồ Chí Minh cơ sở a, Ho Chi Minh City, Vietnam Khoảng cách: 1.21 km&lt;/div&gt;`)[0];
#                 popup_99649d6b8b7917a53c0aaa7dd2159971.setContent(html_fe1e203db46ace340ad02bc24ed88107);
#
#
#
#         marker_baed84f1017ed788a1a97804bd8f3aa4.bindPopup(popup_99649d6b8b7917a53c0aaa7dd2159971)
#         ;
#
#
#
#
#                 marker_baed84f1017ed788a1a97804bd8f3aa4.setIcon(icon_0ae15e1abe1de6a58a7dc09354e119ec);
#
#
#             var marker_927dc6cbab702a42bdb78bbcbcbc9132 = L.marker(
#                 [10.7609491, 106.6679786],
#                 {
# }
#             ).addTo(map_74ff795a9d76d1097d34df80897306bf);
#
#
#             var icon_5ad01b5fda55c4dfaf9d4a875862d539 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c4d8e68fca7e6c70b09ac0b2217a5817 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_51c1dfad78be6b561e6af310ff6c4ff9 = $(`&lt;div id=&quot;html_51c1dfad78be6b561e6af310ff6c4ff9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Đại học Kinh Tế Thành Phố Hồ Chí Minh cơ sở b, Ho Chi Minh City, Vietnam Khoảng cách: 3.53 km&lt;/div&gt;`)[0];
#                 popup_c4d8e68fca7e6c70b09ac0b2217a5817.setContent(html_51c1dfad78be6b561e6af310ff6c4ff9);
#
#
#
#         marker_927dc6cbab702a42bdb78bbcbcbc9132.bindPopup(popup_c4d8e68fca7e6c70b09ac0b2217a5817)
#         ;
